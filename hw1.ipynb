# %% [markdown]
# Условие 3: Дан список с затратами на рекламу. Но в данных есть ошибки, некоторые затраты имеют отрицательную величину. Удалите такие значения из списка и посчитайте суммарные затраты [100, 125, -90, 345, 655, -1, 0, 200] Используйте list comprehensions

# %%
list = [100, 125, -90, 345, 655, -1, 0, 200]
list = [i for i in list if i>0]
sum = 0
for i in list:
    sum = sum+i
sum
# Out:
# 1425

# %% [markdown]
# Условие 4.1: Даны два списка.
#
# Дата покупки ['2021-09-14', '2021-12-15', '2021-09-08', '2021-12-05', '2021-10-09', '2021-09-30', '2021-12-22', '2021-11-29', '2021-12-24', '2021-11-26', '2021-10-27', '2021-12-18', '2021-11-09', '2021-11-23', '2021-09-27', '2021-10-02', '2021-12-27', '2021-09-20', '2021-12-13', '2021-11-01', '2021-11-09', '2021-12-06', '2021-12-08', '2021-10-09', '2021-10-31', '2021-09-30', '2021-11-09', '2021-12-13', '2021-10-26', '2021-12-09']
#
# Суммы покупок по датам [1270, 8413, 9028, 3703, 5739, 4095, 295, 4944, 5723, 3701, 4471, 651, 7037, 4274, 6275, 4988, 6930, 2971, 6592, 2004, 2822, 519, 3406, 2732, 5015, 2008, 316, 6333, 5700, 2887]
#
# 4.1 Найдите, какая выручка у компании в ноябре Используйте list comprehensions

# %%
import pandas as pd

dat = ['2021-09-14', '2021-12-15', '2021-09-08', '2021-12-05', '2021-10-09', '2021-09-30', '2021-12-22',
        '2021-11-29', '2021-12-24', '2021-11-26', '2021-10-27', '2021-12-18', '2021-11-09', '2021-11-23',
        '2021-09-27', '2021-10-02', '2021-12-27', '2021-09-20', '2021-12-13', '2021-11-01', '2021-11-09',
        '2021-12-06', '2021-12-08', '2021-10-09', '2021-10-31', '2021-09-30', '2021-11-09', '2021-12-13',
        '2021-10-26', '2021-12-09']
summ= [1270, 8413, 9028, 3703, 5739, 4095, 295, 4944, 5723, 3701, 4471, 651, 7037, 4274, 6275,
           4988, 6930, 2971, 6592, 2004, 2822, 519, 3406, 2732, 5015, 2008, 316, 6333, 5700, 2887]


dot = pd.DataFrame(summ, index=pd.to_datetime(dat))
print(dot[dot.index.month==11].sum()[0])
# Out:
# 25098

# %%
date = ['2021-09-14', '2021-12-15', '2021-09-08', '2021-12-05', '2021-10-09', '2021-09-30', '2021-12-22', '2021-11-29', '2021-12-24', '2021-11-26', '2021-10-27', '2021-12-18', '2021-11-09', '2021-11-23', '2021-09-27', '2021-10-02', '2021-12-27', '2021-09-20', '2021-12-13', '2021-11-01', '2021-11-09', '2021-12-06', '2021-12-08', '2021-10-09', '2021-10-31', '2021-09-30', '2021-11-09', '2021-12-13', '2021-10-26', '2021-12-09']
revenue = [1270, 8413, 9028, 3703, 5739, 4095, 295, 4944, 5723, 3701, 4471, 651, 7037, 4274, 6275, 4988, 6930, 2971, 6592, 2004, 2822, 519, 3406, 2732, 5015, 2008, 316, 6333, 5700, 2887]

sum([i[1] for i in list(zip(date, revenue)) if "2021-11-" in i[0]])

# %%
date = ['2021-09-14', '2021-12-15', '2021-09-08', '2021-12-05', '2021-10-09', '2021-09-30', '2021-12-22', '2021-11-29', '2021-12-24', '2021-11-26', '2021-10-27', '2021-12-18', '2021-11-09', '2021-11-23', '2021-09-27', '2021-10-02', '2021-12-27', '2021-09-20', '2021-12-13', '2021-11-01', '2021-11-09', '2021-12-06', '2021-12-08', '2021-10-09', '2021-10-31', '2021-09-30', '2021-11-09', '2021-12-13', '2021-10-26', '2021-12-09']
revenue = [1270, 8413, 9028, 3703, 5739, 4095, 295, 4944, 5723, 3701, 4471, 651, 7037, 4274, 6275, 4988, 6930, 2971, 6592, 2004, 2822, 519, 3406, 2732, 5015, 2008, 316, 6333, 5700, 2887]


result = {}
for i in range(len(revenue)):
    result[date[i]] = revenue[i]
result
# Out:
# {'2021-09-14': 1270,
#  '2021-12-15': 8413,
#  '2021-09-08': 9028,
#  '2021-12-05': 3703,
#  '2021-10-09': 2732,
#  '2021-09-30': 2008,
#  '2021-12-22': 295,
#  '2021-11-29': 4944,
#  '2021-12-24': 5723,
#  '2021-11-26': 3701,
#  '2021-10-27': 4471,
#  '2021-12-18': 651,
#  '2021-11-09': 316,
#  '2021-11-23': 4274,
#  '2021-09-27': 6275,
#  '2021-10-02': 4988,
#  '2021-12-27': 6930,
#  '2021-09-20': 2971,
#  '2021-12-13': 6333,
#  '2021-11-01': 2004,
#  '2021-12-06': 519,
#  '2021-12-08': 3406,
#  '2021-10-31': 5015,
#  '2021-10-26': 5700,
#  '2021-12-09': 2887}

# %%
def get_dict(keys:list, values:list) -> dict:
    return {keys[i]:values[i] for i in range(len(values))}
table = get_dict(date,revenue)
table
# Out:
# {'2021-09-14': 1270,
#  '2021-12-15': 8413,
#  '2021-09-08': 9028,
#  '2021-12-05': 3703,
#  '2021-10-09': 2732,
#  '2021-09-30': 2008,
#  '2021-12-22': 295,
#  '2021-11-29': 4944,
#  '2021-12-24': 5723,
#  '2021-11-26': 3701,
#  '2021-10-27': 4471,
#  '2021-12-18': 651,
#  '2021-11-09': 316,
#  '2021-11-23': 4274,
#  '2021-09-27': 6275,
#  '2021-10-02': 4988,
#  '2021-12-27': 6930,
#  '2021-09-20': 2971,
#  '2021-12-13': 6333,
#  '2021-11-01': 2004,
#  '2021-12-06': 519,
#  '2021-12-08': 3406,
#  '2021-10-31': 5015,
#  '2021-10-26': 5700,
#  '2021-12-09': 2887}

# %%
table = get_dict(date,revenue)

def criete_dict (base_dict:dict, keys:list=['2021-09-14','2021-12-15']) -> dict:
    result={}
    for i in keys:
        result[i]=base_dict[i]
    return result



criete_dict (table)
# Out:
# {'2021-09-14': 1270, '2021-12-15': 8413}

# %%
keys=['2021-09-14','2021-12-15']
new_dict={i: table[i] for i in keys}
new_dict
# Out:
# {'2021-09-14': 1270, '2021-12-15': 8413}
